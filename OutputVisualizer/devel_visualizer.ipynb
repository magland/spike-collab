# %%
## Prerequisites: mountainlab_pytools
##    conda install -c flatiron -c mountainlab_pytools

# %%
# For development purposes, reload imported modules when source changes
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dirname='kbucket://b5ecdf1474c5/datasets/synth_datasets/datasets/synth_tetrode_30min'
#dirname='kbucket://22f3e72dd783/groundtruth/boyden/1103_1_1'
raw=dirname+'/raw.mda'
firings_true=dirname+'/firings_true.mda'
geom=dirname+'/geom.csv'

# %%
import devel_visualizer as DV

# %%
output_analyzer=DV.PlaceholderOutputAnalyzer(timeseries=raw,firings=firings_true,geom=geom)
output_analyzer.initialize() # Normally (ideally) we would not need an initialization
print('This spike sorting output has {} units.'.format(output_analyzer.getUnitCount()))
output_visualizer=DV.OutputVisualizer(output_analyzer)
# Out:
# Downloading timeseries (if needed): kbucket://b5ecdf1474c5/datasets/synth_datasets/datasets/synth_tetrode_30min/raw.mda
# Downloading firings (if needed): kbucket://b5ecdf1474c5/datasets/synth_datasets/datasets/synth_tetrode_30min/firings_true.mda
# Downloading geom (if needed): kbucket://b5ecdf1474c5/datasets/synth_datasets/datasets/synth_tetrode_30min/geom.csv
# Reading arrays into memory...
# This spike sorting output has 20 units.

# %%
output_visualizer.viewUnitWaveforms(units=[1,2,3,4],channels=[1,2,3,4])

# %%
output_visualizer.viewUnitWaveforms()
